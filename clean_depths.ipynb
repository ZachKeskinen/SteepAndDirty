# %%
from pathlib import Path
import pandas as pd

from parsers import parse_boise, parse_cameron_pass, parse_fraser, parse_senator_beck

res = pd.DataFrame()

raw_dir = Path('SnowEx2021_TimeSeries_DepthTransects/raw')

parser = {'Boise River': parse_boise, 'Senator Beck': parse_senator_beck, \
          'Fraser': parse_fraser, 'Cameron Pass': parse_cameron_pass}

for loc_dir in raw_dir.glob('*'):
    print(loc_dir)
    # if loc_dir.name != 'Cameron Pass':
    #     continue

    for date_dir in loc_dir.glob('*'):
        for fp in date_dir.joinpath('Depth Transects').glob('*'):
            df = parser[loc_dir.name](fp)
            df['date'] = pd.to_datetime(date_dir.name).strftime('%Y-%m-%d')
            df['Location'] = loc_dir.name
            # print(df['site'])
            res = pd.concat([res, df], ignore_index = True)
# Out:
# SnowEx2021_TimeSeries_DepthTransects/raw/.DS_Store
# SnowEx2021_TimeSeries_DepthTransects/raw/Senator Beck
# SnowEx2021_TimeSeries_DepthTransects/raw/Boise River
# SnowEx2021_TimeSeries_DepthTransects/raw/Fraser
# SnowEx2021_TimeSeries_DepthTransects/raw/Cameron Pass

# %%
res
# Out:
#       depth    observer                                         instrument  \
# 0       122  A.G., M.D.                                                NaN
# 1       138  A.G., M.D.                                                NaN
# 2       166  A.G., M.D.                                                NaN
# 3       163  A.G., M.D.                                                NaN
# 4       153  A.G., M.D.                                                NaN
# ...     ...         ...                                                ...
# 12098   174         NaN  SnowMetrics Probe + Mesa2 tablet + Geode GPS unit
# 12099   156         NaN  SnowMetrics Probe + Mesa2 tablet + Geode GPS unit
# 12100   145         NaN  SnowMetrics Probe + Mesa2 tablet + Geode GPS unit
# 12101   128         NaN  SnowMetrics Probe + Mesa2 tablet + Geode GPS unit
# 12102   125         NaN  SnowMetrics Probe + Mesa2 tablet + Geode GPS unit
#
#            comments                     geometry        date      Location  \
# 0                SP  POINT (-107.71704 37.90065)  2021-02-10  Senator Beck
# 1               NaN  POINT (-107.71705 37.90067)  2021-02-10  Senator Beck
# 2               NaN  POINT (-107.71704 37.90069)  2021-02-10  Senator Beck
# 3               NaN  POINT (-107.71705 37.90072)  2021-02-10  Senator Beck
# 4               NaN  POINT (-107.71705 37.90074)  2021-02-10  Senator Beck
# ...             ...                          ...         ...           ...
# 12098  Out-of-track  POINT (-105.89257 40.51976)  2021-03-18  Cameron Pass
# 12099  Out-of-track  POINT (-105.89250 40.51981)  2021-03-18  Cameron Pass
# 12100  Out-of-track  POINT (-105.89245 40.51986)  2021-03-18  Cameron Pass
# 12101  Out-of-track  POINT (-105.89240 40.51991)  2021-03-18  Cameron Pass
# 12102  Out-of-track  POINT (-105.89233 40.51996)  2021-03-18  Cameron Pass
#
#          site
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 12098  COCPMR
# 12099  COCPMR
# 12100  COCPMR
# 12101  COCPMR
# 12102  COCPMR
#
# [12103 rows x 8 columns]
